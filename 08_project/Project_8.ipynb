# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Андрей, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Критичные ошибки, которые обязательно нужно исправить.
# </div>
#
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Комментарий ревьюера </b>
#
# Андрей, я вижу, что исполнение твоего кода начинается в ячейке с номером, который отличается от единицы. Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
#
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)
#
# Важно также убедиться, что все ячейки проекта исполнились - можно просто пролистать работу до конца и убедиться, что последняя ячейка исполнена. Такая проверка поможет тебе убедиться, что твоё решение будет должным образом воспроизведено во время ревью или во время передачи его заказчику - это очень важный этап, пренебрегать которым не стоит:)
#
# На втором сборном проекте проверка воспроизводимости кода - одно из ключевых условий начала работы над ним. Убедись, пожалуйста, что проект работает, перед отправкой на следующую итерацию.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Привет, Алексей! Да в самом конце я не смог разобраться с некоторыми ошибками и прошу в этом помощи.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Давай посмотрим:)

# %% [markdown]
# ## Описание проекта

# %% [markdown]
#  HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников. В этом HR-аналитикам пригодится машинное обучение, с помощью которого получится быстрее и точнее отвечать на вопросы бизнеса.
#
# Компания предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
# Собирать данные такими опросниками не так легко: компания большая, и всех сотрудников надо сначала оповестить об опросе, а затем проследить, что все его прошли.
#
#
# Первая задача — построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
# Почему бизнесу это важно: удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.
#
# Вторая задача — построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.

# %% [markdown]
# ###### Описание данных.

# %% [markdown]
# Первая задача
#
# - id — уникальный идентификатор сотрудника;
# - dept — отдел, в котором работает сотрудник;
# - level — уровень занимаемой должности;
# - workload — уровень загруженности сотрудника;
# - employment_years — длительность работы в компании (в годах);
# - last_year_promo — показывает, было ли повышение за последний год;
# - last_year_violations — показывает, нарушал ли сотрудник трудовой договор за последний год;
# - supervisor_evaluation — оценка качества работы сотрудника, которую дал руководитель;
# - salary — ежемесячная зарплата сотрудника;
# - job_satisfaction_rate — уровень удовлетворённости сотрудника работой в компании, целевой признак.

# %% [markdown]
# Вторая задача
#
# Для этой задачи те же входные признаки, что и в предыдущей задаче. Однако целевой признак отличается: это quit — увольнение сотрудника из компании.

# %% [markdown]
# ## План работы

# %% [markdown]
# Работа устроена следующим образом:
# - В главе 3 загружаем библиотеки, надостающие пакеты. Также загружаем все входные данные проверяя их на соответствие с описанием.
# - Глава 4 посвещена решению первой задачи.
#     - Первым пунктом идет предобработка данных. Смотрим и исправляем опечатки в категорийных признаках, пропуски , дубликаты и аномалии.
#     - Затем изучаем отдельные распределения данных.
#     - После строим корреляционные матрицы и проверяем что целевой признак действительно зависит от входных признаков. Проверяем есть ли утечка данных , мультиколлинеарность.
#     - Последним пунктом составляем пайплайн для обучения поиска лучших гиперпараметров для 2 моделей регрессии для предсказания целевого признака `job_satisfaction_rate` : линейной регрессии и решаюшего дерева. Выбираем из них лучшую.
# - Пятая глава имеет ту же структуру что и четвертая, но касается Задачи 2. Первые 3 шага повторяются из 4 главы. Но в конце составляем пайплайн для задачи классификации с целевым признаком `quit`. В этом пайплайне обучаем несколько моделей с набором гиперпараметров и выбираем лучшую.
# - В шестой главе делаем общий вывод и даем рекомендачии заказчику.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# ### Загрузка библиотек.

# %%
# !pip install phik -q
# !pip install shap -q
# !pip install scikit-learn==1.4.2 -q
# !pip install matplotlib==3.5.3 -q
# !pip install imbalanced-learn -q
# !pip install seaborn==0.13.2 -q

# %%
import shap
import plotly.graph_objs as go
import plotly.offline as pyo
import numpy as np
from sklearn.datasets import make_classification
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import phik
import os
from scipy.stats import shapiro
import scipy.stats as stats
from imblearn.over_sampling import RandomOverSampler


from sklearn.model_selection import train_test_split

# загружаем класс pipeline
from sklearn.pipeline import Pipeline

# загружаем классы для подготовки данных
from sklearn.preprocessing import (
    OneHotEncoder, 
    OrdinalEncoder,
    LabelEncoder,
    StandardScaler, 
    MinMaxScaler, 
    RobustScaler
)   
from sklearn.compose import ColumnTransformer

# загружаем класс для работы с пропусками
from sklearn.impute import SimpleImputer

# загружаем функцию для работы с метриками
from sklearn.metrics import (
    roc_auc_score,
    roc_curve,
    confusion_matrix,
    make_scorer
)

# импортируем класс RandomizedSearchCV
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# загружаем нужные модели
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.svm import SVC
from sklearn.dummy import DummyRegressor

# Константы

RANDOM_STATE = 42
TEST_SIZE = 0.25

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %% [markdown]
# ### train_job_satisfaction_rate.csv

# %%
if os.path.exists('/datasets/train_job_satisfaction_rate.csv'):
    df = pd.read_csv('/datasets/train_job_satisfaction_rate.csv',index_col='id')
    display(df.head())
else:
    print('Something is wrong')
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 155278       sales  junior   medium                 2              no
# 653870          hr  junior     high                 2              no
# 184592       sales  junior      low                 1              no
# 171431  technology  junior      low                 4              no
# 693419          hr  junior   medium                 1              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 155278                   no                      1   24000
# 653870                   no                      5   38400
# 184592                   no                      2   12000
# 171431                   no                      2   18000
# 693419                   no                      3   22800
#
#         job_satisfaction_rate
# id
# 155278                   0.58
# 653870                   0.76
# 184592                   0.11
# 171431                   0.37
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 155278 to 338347
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dept                   3994 non-null   object
#  1   level                  3996 non-null   object
#  2   workload               4000 non-null   object
#  3   employment_years       4000 non-null   int64
#  4   last_year_promo        4000 non-null   object
#  5   last_year_violations   4000 non-null   object
#  6   supervisor_evaluation  4000 non-null   int64
#  7   salary                 4000 non-null   int64
#  8   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 312.5+ KB

# %% [markdown]
# ### test_features.csv

# %%
if os.path.exists('/datasets/test_features.csv'):
    X_test = pd.read_csv('/datasets/test_features.csv',index_col='id')
    display(X_test.head())
else:
    print('Something is wrong')
# Out:
#              dept   level workload  employment_years last_year_promo  \
# id
# 485046  marketing  junior   medium                 2              no
# 686555         hr  junior   medium                 1              no
# 467458      sales  middle      low                 5              no
# 418655      sales  middle      low                 6              no
# 789145         hr  middle   medium                 5              no
#
#        last_year_violations  supervisor_evaluation  salary
# id
# 485046                   no                      5   28800
# 686555                   no                      4   30000
# 467458                   no                      4   19200
# 418655                   no                      4   19200
# 789145                   no                      5   40800

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 485046 to 771859
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dept                   1998 non-null   object
#  1   level                  1999 non-null   object
#  2   workload               2000 non-null   object
#  3   employment_years       2000 non-null   int64
#  4   last_year_promo        2000 non-null   object
#  5   last_year_violations   2000 non-null   object
#  6   supervisor_evaluation  2000 non-null   int64
#  7   salary                 2000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 140.6+ KB

# %% [markdown]
# ### test_target_job_satisfaction_rate.csv

# %%
if os.path.exists('/datasets/test_target_job_satisfaction_rate.csv'):
    y_test = pd.read_csv('/datasets/test_target_job_satisfaction_rate.csv',index_col='id')
    display(y_test.head())
else:
    print('Something is wrong')
# Out:
#         job_satisfaction_rate
# id
# 130604                   0.74
# 825977                   0.75
# 418490                   0.60
# 555320                   0.72
# 826430                   0.08

# %%
y_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 130604 to 648995
# Data columns (total 1 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1)
# memory usage: 31.2 KB

# %% [markdown]
# ### train_quit.csv

# %%
if os.path.exists('/datasets/train_quit.csv'):
    df2 = pd.read_csv('/datasets/train_quit.csv',index_col='id')
    display(df2.head())
else:
    print('Something is wrong')
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 723290       sales  middle     high                 2              no
# 814010       sales  junior   medium                 2              no
# 155091  purchasing  middle   medium                 5              no
# 257132       sales  junior   medium                 2              no
# 910140   marketing  junior   medium                 2              no
#
#        last_year_violations  supervisor_evaluation  salary quit
# id
# 723290                   no                      4   54000   no
# 814010                   no                      4   27600   no
# 155091                   no                      1   37200   no
# 257132                  yes                      3   24000  yes
# 910140                   no                      5   25200   no

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 723290 to 853842
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dept                   4000 non-null   object
#  1   level                  4000 non-null   object
#  2   workload               4000 non-null   object
#  3   employment_years       4000 non-null   int64
#  4   last_year_promo        4000 non-null   object
#  5   last_year_violations   4000 non-null   object
#  6   supervisor_evaluation  4000 non-null   int64
#  7   salary                 4000 non-null   int64
#  8   quit                   4000 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 312.5+ KB

# %% [markdown]
# ### test_target_quit.csv

# %%
if os.path.exists('/datasets/test_target_quit.csv'):
    z_test = pd.read_csv('/datasets/test_target_quit.csv',index_col='id')
    display(z_test.head())
else:
    print('Something is wrong')
# Out:
#        quit
# id
# 999029  yes
# 372846   no
# 726767   no
# 490105   no
# 416898  yes

# %%
z_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 999029 to 460332
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   quit    2000 non-null   object
# dtypes: object(1)
# memory usage: 31.2+ KB

# %% [markdown]
# ### Вывод

# %% [markdown]
# Данные загружены и соответствуют описанию.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Данные загружены. Молодец, что используешь `os` для загрузки данных, а также задаёшь столбец-индекс.

# %% [markdown]
# ## Задача 1

# %% [markdown]
# ###  Предобработка

# %% [markdown]
# #### Категорийные признаки.

# %%
df_cat_columns = ['dept','level','workload','last_year_promo','last_year_violations' ]
for i in df_cat_columns:
    print(df[i].unique())
# Out:
# ['sales' 'hr' 'technology' 'purchasing' 'marketing' nan]
# ['junior' 'middle' 'sinior' nan]
# ['medium' 'high' 'low']
# ['no' 'yes']
# ['no' 'yes']

# %%
df.loc[df['level']=='sinior','level'] = 'senior'

# %%
for i in df_cat_columns:
    print(X_test[i].unique())
# Out:
# ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan ' ']
# ['junior' 'middle' 'sinior' nan]
# ['medium' 'low' 'high' ' ']
# ['no' 'yes']
# ['no' 'yes']

# %%
X_test.loc[X_test['level']=='sinior','level'] = 'senior'

# %% [markdown]
# Исправили сразу печатку в названии категории sinior вместо senior . Но есть пропущенные значения.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Также можно было бы исправить ошибку в `sinior`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Спасибо , поправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# #### Пропуски

# %% [markdown]
# Посмотрим есть ли пропуски. Для удобства примедем тренировочные данные и тестовые к одному виду.

# %%
X_test = X_test.sort_index()
y_test = y_test.sort_index()
X_test['job_satisfaction_rate'] = y_test['job_satisfaction_rate']
X_test
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 100298          hr  junior      low                 2              no
# 100480   marketing  junior      low                 4              no
# 100503  purchasing  middle     high                 5              no
# 100610       sales  middle   medium                 5              no
# 100692       sales  middle     high                 6              no
# ...            ...     ...      ...               ...             ...
# 997290       sales  senior   medium                 7              no
# 998548   marketing  junior   medium                 2              no
# 998762  technology  junior      low                 3              no
# 998900   marketing  middle   medium                 7              no
# 999029  technology  junior   medium                 1              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# ...

# %%
df.isna().sum()
# Out:
# dept                     6
# level                    4
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# job_satisfaction_rate    0
# dtype: int64

# %%
X_test.isna().sum()
# Out:
# dept                     2
# level                    1
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# job_satisfaction_rate    0
# dtype: int64

# %%
X_test.loc[(X_test['dept']==' ')|(X_test['level']==' ')]
# Out:
#        dept   level workload  employment_years last_year_promo  \
# id
# 822186       middle   medium                 3              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 822186                   no                      4   38400
#
#         job_satisfaction_rate
# id
# 822186                   0.64

# %% [markdown]
# Есть и их не много. Можем заполнить их. Вот пайплайн который это делает.

# %% [markdown]
# Пропусков не много я их удалил. Пытался сделать это пайплайном ниже , пропуски заполняет. Но почему то меняет пипы данных, я не понял почему.

# %%
col_gap = ['dept','level','workload']
gap_pipe = Pipeline(
    [
           ( 'gap1', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
           ),
           ( 'gap2', 
            SimpleImputer(missing_values=' ', strategy='most_frequent')
           )
    ]
) 

data_gap = ColumnTransformer(
    [
        ('gap', gap_pipe, col_gap)
    ], 
    remainder='passthrough'
)

# %% [markdown]
# Используем пайплайн и вернем датафрейм в нормальный вид.

# %%
df['id'] = df.index
columns = df.columns
df = pd.DataFrame(
    data_gap.fit_transform(df),
    columns=columns
    )
df['employment_years'] = df['employment_years'].astype(int)
df['supervisor_evaluation'] = df['supervisor_evaluation'].astype(int)
df['salary'] = df['salary'].astype(int)
df['job_satisfaction_rate'] = df['job_satisfaction_rate'].astype(float)
df = df.set_index('id')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 155278 to 338347
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dept                   4000 non-null   object
#  1   level                  4000 non-null   object
#  2   workload               4000 non-null   object
#  3   employment_years       4000 non-null   int64
#  4   last_year_promo        4000 non-null   object
#  5   last_year_violations   4000 non-null   object
#  6   supervisor_evaluation  4000 non-null   int64
#  7   salary                 4000 non-null   int64
#  8   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 312.5+ KB

# %%
 df.loc[(df['dept'].isna())|(df['level'].isna())]
# Out:
# Empty DataFrame
# Columns: [dept, level, workload, employment_years, last_year_promo, last_year_violations, supervisor_evaluation, salary, job_satisfaction_rate]
# Index: []

# %%
X_test['id'] = X_test.index
columns=X_test.columns
X_test = pd.DataFrame(
    data_gap.transform(X_test),
    columns=columns
    )
X_test['employment_years'] = X_test['employment_years'].astype(int)
X_test['supervisor_evaluation'] = X_test['supervisor_evaluation'].astype(int)
X_test['salary'] = X_test['salary'].astype(int)
X_test['job_satisfaction_rate'] = X_test['job_satisfaction_rate'].astype(float)
X_test = X_test.set_index('id')
X_test
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 100298          hr  junior      low                 2              no
# 100480   marketing  junior      low                 4              no
# 100503  purchasing  middle     high                 5              no
# 100610       sales  middle   medium                 5              no
# 100692       sales  middle     high                 6              no
# ...            ...     ...      ...               ...             ...
# 997290       sales  senior   medium                 7              no
# 998548   marketing  junior   medium                 2              no
# 998762  technology  junior      low                 3              no
# 998900   marketing  middle   medium                 7              no
# 999029  technology  junior   medium                 1              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Инструменты трансформации выборок нельзя обучать на `test`: так как `test` выборка имитирует поток реальных данных, с которыми работает модель, то, во-первых, `test` выборки в реальной среде работы модели не будет, и твой пайплайн с моделью упадёт, во-вторых, так мы даём модели данные из будущего, которые в нормальных условиях она не могла бы увидеть - в `test` вполне могут быть новые категории, отсутствующие в `train` (если говорить про кодирование), или распределение переменных в `test` может сильно отличаться от распределения в `train` (если говорить про стандартизацию).
#
# Единственно верный порядок работы с такими инструментами - обучаемся на `train` (для `train` можно использовать `fit_transform()`), и уже обученным на `train` инструментом изменяем выборки `train`, `test` и `valid` (если выделялась).

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Спасибо , поправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
X_test.loc[(X_test['dept'].isna())|(X_test['level'].isna())|(X_test['workload'].isna())]
# Out:
# Empty DataFrame
# Columns: [dept, level, workload, employment_years, last_year_promo, last_year_violations, supervisor_evaluation, salary, job_satisfaction_rate]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 155278 to 338347
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dept                   4000 non-null   object
#  1   level                  4000 non-null   object
#  2   workload               4000 non-null   object
#  3   employment_years       4000 non-null   int64
#  4   last_year_promo        4000 non-null   object
#  5   last_year_violations   4000 non-null   object
#  6   supervisor_evaluation  4000 non-null   int64
#  7   salary                 4000 non-null   int64
#  8   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 312.5+ KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 100298 to 999029
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dept                   2000 non-null   object
#  1   level                  2000 non-null   object
#  2   workload               2000 non-null   object
#  3   employment_years       2000 non-null   int64
#  4   last_year_promo        2000 non-null   object
#  5   last_year_violations   2000 non-null   object
#  6   supervisor_evaluation  2000 non-null   int64
#  7   salary                 2000 non-null   int64
#  8   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 156.2+ KB

# %%
X_test.loc[(X_test['dept']==' ')|(X_test['level']==' ')]
# Out:
# Empty DataFrame
# Columns: [dept, level, workload, employment_years, last_year_promo, last_year_violations, supervisor_evaluation, salary, job_satisfaction_rate]
# Index: []

# %% [markdown]
# Все заполнили.

# %% [markdown]
# #### Дубликаты

# %%
print(df.duplicated().sum())
# Out:
# 248

# %%
df.index.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Признаков не так много и много категорийных по этому дубликаты вполне естественны.

# %% [markdown]
# #### Аномалии

# %%
df.describe()
# Out:
#        employment_years  supervisor_evaluation        salary  \
# count       4000.000000            4000.000000   4000.000000
# mean           3.718500               3.476500  33926.700000
# std            2.542513               1.008812  14900.703838
# min            1.000000               1.000000  12000.000000
# 25%            2.000000               3.000000  22800.000000
# 50%            3.000000               4.000000  30000.000000
# 75%            6.000000               4.000000  43200.000000
# max           10.000000               5.000000  98400.000000
#
#        job_satisfaction_rate
# count            4000.000000
# mean                0.533995
# std                 0.225327
# min                 0.030000
# 25%                 0.360000
# 50%                 0.560000
# 75%                 0.710000
# max                 1.000000

# %% [markdown]
# Проверим что совпадают ли данные по сотрудникам в X_test y_test.

# %%
(X_test.index != y_test.index).sum()
# Out:
# 0

# %% [markdown]
# Аномалий не замечено.

# %% [markdown]
# #### Вывод

# %% [markdown]
# Данные хорошего качества вся предобработка свелась к заполнению нескольких пропусков.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# С предобработкой данных порядок.

# %% [markdown]
# ### Исследовательский анализ

# %% [markdown]
# #### df

# %% [markdown]
# Анализ тренировочной выборки.
# Создадим переменные для дискретных и неприрывных численных столбцов и для категорийных столбцов.
# Длительность для удобства переведем в неприрывные столбцы.

# %%
def analysis(df):
    df['salary'] = df['salary'].astype(float)
    con = df.select_dtypes(include=['float']).columns.tolist()
    dis = df.select_dtypes(include=['int']).columns.tolist()
    cat = df.select_dtypes(exclude=['int','float']).columns.tolist()
    print(f'Список неприрывных признаков {con}')
    print(f'Список дискретныйх признаков {dis}')
    print(f'Список категорийных признаков {cat}')
    
    print(f'----------------------------------------')
    print(f'Графики неприрывных признаков')
    
    for i in con:
        plt.figure(figsize=(10,4))
        plt.subplot(1,2,1)
        df[i].hist(bins=30)
        plt.title(f'Зависимость числа сотрудников от {i}')
        plt.xlabel(i)
        plt.ylabel('Число сотрудников')
    
        plt.subplot(1,2,2)
        df[i].plot(kind='box')
        plt.title('')
        plt.ylabel('')
    
    
        plt.show()
    
        stat, p = shapiro(df[i])
        if p>0.05:
            print(f'p={p:.3} Вероятно нормальное')
        else :
            print(f'p={p:.3} Вероятно не нормальное')
    
    print(df[con].describe())
    
    print(f'----------------------------------------')
    print(f'Графики дискретных признаков')
    
        
    for i in dis:
        plt.figure(figsize=(10,4))
        plt.subplot(1,2,1)
        sns.countplot(data=df,x=i)
        plt.title(f'Зависимость числа сотрудников от {i}')
        plt.xlabel(i)
        plt.ylabel('Число сотрудников')
    
        plt.subplot(1,2,2)
        df[i].plot(kind='box')
        plt.title('')
        plt.ylabel('')
    
    
        plt.show()
    
    print(f'----------------------------------------')
    print(f'Графики категорийных признаков')
    
    for i in cat:
        (df.pivot_table(index=i,values='salary',aggfunc='count')\
        .sort_values(by='salary',ascending=False)/df.shape[0])\
        .plot(kind='bar',rot='45',legend=False)
        plt.xlabel(i)
        plt.ylabel('Число сотрудников')
        plt.show()

analysis(df)
# Out:
# Список неприрывных признаков ['salary', 'job_satisfaction_rate']
# Список дискретныйх признаков ['employment_years', 'supervisor_evaluation']
# Список категорийных признаков ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']
# ----------------------------------------
# Графики неприрывных признаков
# p=8.4e-38 Вероятно не нормальное
# p=8.91e-28 Вероятно не нормальное
#              salary  job_satisfaction_rate
# count   4000.000000            4000.000000
# mean   33926.700000               0.533995
# std    14900.703838               0.225327
# min    12000.000000               0.030000
# 25%    22800.000000               0.360000
# 50%    30000.000000               0.560000
# 75%    43200.000000               0.710000
# max    98400.000000               1.000000
# ----------------------------------------
# Графики дискретных признаков
# ----------------------------------------
# Графики категорийных признаков

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Пытался для countplot применить  `stat='percent'` в документации есть такой пареметр и версия подходит. Но почему то ошмбка 'Rectangle' object has no property 'stat'
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Возможно, дело в версии библиотеки - на платформе обычно не самая актуальна. Посмотри, в какой версии появились эти опции, и обновись до нужной версии библиотеки.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Появилась в 0.12 , я поставил 0.13 в начале...
# </div>

# %% [markdown]
# #### X_test

# %% [markdown]
# Анализ тестовой выборки.

# %%
analysis(X_test)
# Out:
# Список неприрывных признаков ['salary', 'job_satisfaction_rate']
# Список дискретныйх признаков ['employment_years', 'supervisor_evaluation']
# Список категорийных признаков ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']
# ----------------------------------------
# Графики неприрывных признаков
# p=2.13e-30 Вероятно не нормальное
# p=5.12e-20 Вероятно не нормальное
#              salary  job_satisfaction_rate
# count   2000.000000             2000.00000
# mean   34066.800000                0.54878
# std    15398.436729                0.22011
# min    12000.000000                0.03000
# 25%    22800.000000                0.38000
# 50%    30000.000000                0.58000
# 75%    43200.000000                0.72000
# max    96000.000000                1.00000
# ----------------------------------------
# Графики дискретных признаков
# ----------------------------------------
# Графики категорийных признаков

# %% [markdown]
# #### Вывод

# %% [markdown]
# При анализе распределений видим следующее:
# В тренировочной выборке и тестовой выборке распределения одих признаков близки.
# - Salary распределение далеко от нормального есть длинный хвост из выбросов в сторону высокой зарплаты.
# - Job_satisfaction_rate так же распределение не нормальное. Есть несколько пиков на 0.4 и 0.7.
# - employment_years Видно что число сотрудников почти линейно падает в зависимости от стажа.
# - supervisor_evaluation Преобладающая оценка 4 и 3. 5 и 2 мало. 1 редкость.
# - dept самый популярный департамент sales  затем technology. Остальные 3 примерно на одном уровне.
# - level . junior middle примерно равны по численности , senior гораздо меньше.
# - workload Сотрудников со средней загрузкой больше всего , затем идут с низкой нагрузкой, и меньше всего сотрудников с высокой нагрузкой.
# - last_year_promo Сотрудников которых повышели очень мало.
# - last_year_violations нарушителей тоже мало относительно не нарушавших.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Есть EDA признаков - молодец, что используешь разные инструменты для разных признаков.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Выводы по EDA стоит расширить - нужно сделать вывод по каждому признаку и по `train`, и по `test`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Добавил слов.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### Корреляционный анализ

# %% [markdown]
# Поскольку распределение признаков не является нормальным, для поиска корреляций будем использовать кореляции Спирмана и $\phi_k$.

# %% [markdown]
# #### Тренировочные данные.

# %% [markdown]
# ##### Корреляция Спирмена

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(method='spearman'),annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# ##### Корреляция  $\phi_k$

# %%
con = df.select_dtypes(include=['float']).columns.tolist()
con
# Out:
# ['salary', 'job_satisfaction_rate']

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> `employment_years` и `supervisor_evaluation` - дискретные признаки, их не нужно передавать в `interval_cols`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# В con только ['salary', 'job_satisfaction_rate'] .
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.phik_matrix(interval_cols=con),annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# ##### Корреляция Спирмена

# %%
plt.figure(figsize=(10,10))
sns.heatmap(X_test.corr(method='spearman'),annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# ##### Корреляция  $\phi_k$

# %%
plt.figure(figsize=(10,10))
sns.heatmap(X_test.phik_matrix(interval_cols=con),annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# #### Вывод

# %% [markdown]
# Мультиколлинеарности нет.
# Матрицы для обоих видов корреляции в случае тестовой и тренировочной выборки почти совпадают. т.е. Если есть корреляция в тестовой выборке она есть и ее величина почти та же, что и в тренировочной, и наоборот. Значит модель, обученая на данных тренировочной выборки, будет работать и на тестовой выборке с высокой вероятностью.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Есть анализ корреляции - молодец, что используешь `phik` для анализа и нелинейных зависимостей, а также настраиваешь `interval_cols` для корректной оценки корреляции для переменных разного типа.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Корреляционный анализ нужно провести также для `test` выборки: так как мы не сами занимались разделением данных на выборки, мы должны убедиться, что в данных нет существенных различий в части распределений признаков и что оценка модели, полученная на `test` выборке, будет корректной.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Спасибо добавил сравнение выборок.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### Пайплайн для обучения модели

# %% [markdown]
# Продолжим составления пайплайна и обучим для сравнения 2 модели решающее дерево и линейную регрессию.
# В качесте метрики используем SMAPE.

# %%
# Создадим явно списки численных и категорийных величин. 
num = ['salary','employment_years', 'supervisor_evaluation']
cat = ['dept', 'last_year_promo', 'last_year_violations']
ord_cat = ['level','workload']

# Удаляем дубликаты их тренировочной выборки.
df = df.drop_duplicates()
df.duplicated().sum()

X_train = df.drop(['job_satisfaction_rate'],axis=1)
X_test = X_test.drop(['job_satisfaction_rate'],axis=1)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Перед началом машинного обучения нужно удалить ранее найденные дубликаты. При этом важно проверить только `train`: наличие дубликатов в `test` нам никак не мешает, но это правильное решение с точки зрения неприкосновенности `test`, ведь реальный поток данных (который имитирует `test` выборка) мы исправить не сможем. А вот наличие дубликатов в `train` не только не принесёт пользы модели, но может и навредить.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Но у дубликатов же разные ID. Думаю вполне могут быть сотрудники с одинаковыми полями. Дубликаты удалил. Но в реальности я бы попросил проверить корректность данных.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> С точки зрения EDA это действительно разные люди, и их на этапе EDA удалять не стоит. Но для модели это одно и то же наблюдение, которое может привести к негативным последствиям при обучении.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Понял. Перенес удаление сюда.
# </div>

# %%
y_train = df['job_satisfaction_rate']

X_train.shape, y_train.shape
# Out:
# ((3752, 8), (3752,))

# %%
# создаём пайплайн для подготовки признаков из списка cat: OHE-кодирование
ohe_pipe = Pipeline(
    [
        ('gap',gap_pipe),
        (
            'ohe', 
            OneHotEncoder(drop='first',handle_unknown='ignore', sparse_output=False)
        )
    ]
)

ord_pipe = Pipeline(
    [('gap',gap_pipe),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['junior','middle','senior'],
                    ['low','medium','high']
                ],
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        )
    ]
)

# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, cat),
        ('ord', ord_pipe, ord_cat),
        ('num', RobustScaler(), num)
    ], 
    remainder='passthrough'
)

# создаём итоговый пайплайн: подготовка данных и модель
pipe_final= Pipeline(
    [
        ('preprocessor', data_preprocessor),
        ('models', LinearRegression())
    ]
)

# %% [markdown]
# Создаем метрику SMAPE = $\frac{200}{n}\sum_{i=0}^{n}\frac{|y_i-\hat{y}_i|}{|y_i|+|\hat{y}_i|}$

# %%
# создаём функцию для оценки качества модели

def smape_metric(y_true, y_pred):
    # вычисляем smape
    metric = 200* (abs(y_true-y_pred)/(abs(y_pred)+abs(y_true))).sum()/y_true.count()
    return metric

# создаём пользовательскую метрику
scorer = make_scorer(smape_metric,greater_is_better=False)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть функция для оценки `sMAPE`, а также пользовательский скорринг для кросс-валидации - супер!
# </div>

# %% [markdown]
# #### Линейная регрессия.

# %%
param_grid_linear = [
    # словарь для модели LinearRegression()
    {
        'models': [LinearRegression()],
        'preprocessor__num': [MinMaxScaler(), RobustScaler(), 'passthrough']  
    }
]

# %%
grid_search = GridSearchCV(
    pipe_final, 
    param_grid_linear, 
    cv=5,
    scoring=scorer,
    n_jobs=-1
)
grid_search.fit(X_train, y_train)

print ('Метрика лучшей модели при кросс-валидации выборке:', -grid_search.best_score_)
print('Лучшая модель и её параметры:')
display(grid_search.best_estimator_)
display(grid_search.best_params_)
# Out:
# Метрика лучшей модели при кросс-валидации выборке: 24.991163758389174
# Лучшая модель и её параметры:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('gap',
#                                                                    Pipeline(steps=[('gap1',
#                                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                                    ('gap2',
#                                                                                     SimpleImputer(missing_values=' ',
#                                                                                                   strategy='most_frequent'))])),
#                                                                   ('ohe',
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Найдена лучшая модель.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Обрати внимание, что оценка получена на кросс-валидации, а не на `train` выборке - очень важно корректно разделять эти сущности.
#
# На `train` оценка выглядела бы сделующим образом:
#
#     model.fit(x_train, y_train)
#     preds = model.predict(x_train)
#
#     smape(y_train, preds)
#
# Текст в выводе кода стоит поправить, указав оценку на кросс-валидации.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# Как видишь, твоя метрика имеет отрицательное значение - это особеность работы `make_scorer` с настроенным параметром `greater_is_better=False`: так как метрика `sMAPE` применяется для задач регрессии, то она тем лучше, чем ниже - это нужно учитывать при создании скорринга для кросс-валидации, так как по умолчанию инструменты подбора гиперпараметров и поиска лучшей модели вроде `GridSearchCV` умеют только максимизировать метрику качества. Поэтому при создании скорринга с помощью `make_scorer` важно настроить параметр `greater_is_better=False`, чтобы оптимизируемая метрика минимизировалась, а не максимизировалась - таким образом задача максимизации будет решаться через задачу минимизации обратной функции.
#
# Поэтому при выводе метрики на экран её стоит сделать положительной: взять по модулю, домножить на `-1` или просто указать `-` при выводе на экран, вроде `print(-a)`.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Поправил и то, и другое.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не забывай подписывать оси на графиках.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Ось подписал
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# #### Решаюшее дерево.

# %%
param_grid_tree = [
    # словарь для модели LinearRegression()
    {
        'models': [LinearRegression()],
        'preprocessor__num': [MinMaxScaler(), RobustScaler(), 'passthrough']  
    },
    # словарь для модели DecisionTreeRegressor()
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': [None] + [i for i in range(2, 7)],
        'models__min_samples_leaf': range(2 , 6),
        'models__min_samples_split': range(2 , 6),
        'preprocessor__num': [MinMaxScaler(),RobustScaler(), 'passthrough']
    }
]

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Для гиперпараметра `max_depth` рассматривается очень длинная последовательность: деревья с большой глубиной склонны к переобучению, а обучаются и предсказывают результат они дольше, поэтому делать их слишком глубокими не стоит - оптимальное значение почти всегда лежит в диапазоне от 2 до 5-6. Кроме того, можно попробовать значение `None` - в итоге оптимальная последовательность может выглядеть как `[None] + [i for i in range(2, 7)]`.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Спасибо. Про `None` я как то упустил что можно использовать.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
random_search = RandomizedSearchCV(
    pipe_final, 
    param_grid_tree, 
    cv=5,
    scoring=scorer,
    n_jobs=-1,
    n_iter=120,
    random_state=RANDOM_STATE
)
random_search.fit(X_train, y_train)

print ('Метрика лучшей модели при кросс-валидации:', -random_search.best_score_)
print('Лучшая модель и её параметры:')
display(random_search.best_estimator_)
random_search.best_params_
# Out:
# Метрика лучшей модели при кросс-валидации: 15.247058237963756
# Лучшая модель и её параметры:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('gap',
#                                                                    Pipeline(steps=[('gap1',
#                                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                                    ('gap2',
#                                                                                     SimpleImputer(missing_values=' ',
#                                                                                                   strategy='most_frequent'))])),
#                                                                   ('ohe',
# ...

# %% [markdown]
# Посмотрим метрику на тестовой выборке.

# %%
X_test = X_test
y_test_pred = random_search.best_estimator_.predict(X_test)
metric = scorer(random_search.best_estimator_, X_test, y_test['job_satisfaction_rate'])
print(f'Метрика SMAPE на тестовой выборке: {-metric}')
# Out:
# Метрика SMAPE на тестовой выборке: 13.457898911245461

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# На `test` оцениваем только одну модель, лучшую по итогам кросс-валидации. Эта концепция находит своё отражение в условиях эксплуатации модели в реальной среде: в промышленной эксплуатации не работает несколько моделей одновременно - в промышленную эксплуатацию запускают только одну модель, которая была выбрана из нескольких в ходе промежуточной оценки. Так же и здесь - тестовая выборка имитирует поток реальных данных, и с этим потоком должна работать только одна модель.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Хорошо удалил , эту часть для линейной регрессии.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Метрика лучше требуемых 15. Модель хорошая, но посмотрим еще на распределение остатков.

# %%
def residual_test(y_test,prediction):
    residual = y_test-prediction
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,5))
    axes[0].hist(residual,bins=30)
    axes[0].set_title('Гистограмма распределения остатков')
    axes[0].set_ylabel('Число сотрудников')
    axes[0].set_xlabel('Остатки')

    axes[1].scatter(y=residual,x=prediction )
    axes[1].set_xlabel('Предсказания модели')
    axes[1].set_ylabel('Остатки')
    axes[1].set_title('Анализ дисперсии')
    plt.show()
    return residual.describe()


residual_test(y_test_pred,y_test['job_satisfaction_rate'])
# Out:
# count    2000.000000
# mean        0.001116
# std         0.076066
# min        -0.385000
# 25%        -0.043333
# 50%         0.003333
# 75%         0.048220
# max         0.297500
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# #### DummyRegressor

# %% [markdown]
# Сравним полученную модель с моделью которая предсказывает среднее или медиану по тренировочной выборке.

# %%
y_train
# Out:
# id
# 155278    0.58
# 653870    0.76
# 184592    0.11
# 171431    0.37
# 693419    0.20
#           ...
# 424345    0.88
# 855240    0.27
# 533318    0.76
# 706868    0.48
# 338347    0.18
# Name: job_satisfaction_rate, Length: 3752, dtype: float64

# %%
dumm = DummyRegressor(strategy='median')
       
X_train_p = data_preprocessor.fit_transform(X_train)
X_test_p = data_preprocessor.transform(X_test)

dumm.fit(X_train_p,y_train)
y_test_pred = dumm.predict(X_test_p)

metric = scorer(dumm, X_test_p, y_test['job_satisfaction_rate'])
print(f'Метрика SMAPE на тестовой выборке: {-metric}')
# Out:
# Метрика SMAPE на тестовой выборке: 37.77281981888387

# %%
residual_test(y_test_pred,y_test['job_satisfaction_rate'])
# Out:
# count    2000.00000
# mean        0.00122
# std         0.22011
# min        -0.45000
# 25%        -0.17000
# 50%        -0.03000
# 75%         0.17000
# max         0.52000
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# #### Важность призкаков

# %% [markdown]
# Посчитаем значения Шепли для признаков в лучшей модели выбранной выше.

# %%
num = ['salary','employment_years', 'supervisor_evaluation']
cat = ['dept', 'last_year_promo', 'last_year_violations']
ord_cat = ['level','workload'] 

data_preprocessor_2 = ColumnTransformer(
[
    ('ohe', ohe_pipe, cat),
    ('ord', ord_pipe, ord_cat),
    ('num', MinMaxScaler(), num)
], 
remainder='passthrough'
)

X_train_p = pd.DataFrame(
data_preprocessor_2.fit_transform(X_train),
columns=data_preprocessor_2.get_feature_names_out()
)

X_test_p = pd.DataFrame(
data_preprocessor_2.transform(X_test),
columns=data_preprocessor_2.get_feature_names_out()    
)

X_test_p_sample = X_test_p.sample(n=150,random_state=RANDOM_STATE)
X_train_p_sample = X_train_p.sample(n=150,random_state=RANDOM_STATE)

best_model = DecisionTreeRegressor(min_samples_split=5,min_samples_leaf=3, random_state=42)
best_model.fit(X_train_p,y_train)

explainer = shap.KernelExplainer(best_model.predict,X_train_p_sample)
shap_values = explainer(X_test_p_sample)
# Out:
# Using 150 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/150 [00:00<?, ?it/s]

# %%
fig, ax = plt.gcf(), plt.gca()

# Modifying main plot parameters
ax.tick_params(labelsize=14)
ax.set_xlabel("Средние значения Шепли", fontsize=14)
ax.set_ylabel("Признаки", fontsize=14)
ax.set_title('Важность признаков', fontsize=14)

shap.plots.bar(shap_values[:,:], max_display=11)

plt.show()

# %%
fig, ax = plt.gcf(), plt.gca()


# Modifying main plot parameters
ax.tick_params(labelsize=14)
ax.set_xlabel("Средние значения Шепли", fontsize=14)
ax.set_ylabel("Значения признаков", fontsize=14)
ax.set_title('Важность признаков', fontsize=14)

# Get colorbar
cb_ax = fig.axes[0]

# Modifying color bar parameters
cb_ax.tick_params(labelsize=15)
cb_ax.set_ylabel("Признаки", fontsize=14)
cb_ax.set_xlabel("Средние значения Шепли", fontsize=14)

shap.plots.beeswarm(shap_values[:,:], max_display=11)

plt.show()

# %% [markdown]
# #### Вывод

# %% [markdown]
# Решающее дерево справилось с задачей значительнно лучше линейной регрессии. Это не удивительно т.к в данных есть и выбросы и дисбаланс классов и распределения далеки от нормальных.
# При сравнении с константной моделью так же видно, что решающее дерево дает результат гораздо точнее.
# Искомая метрика на тестовой выборке составила SMAPE=13.6 в случае решающего дерева.
# Распределение остатков для решающего дерева довольно равномерно. Хотя закономерности в распределении остаются.Параметры лучшей модели ниже.
# Наиболее важные признаки в порядке уменьшения значимости: supervisor_evaluation, employment_years, level, salary, last_year_violations, workload

# %%
random_search.best_estimator_
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('gap',
#                                                                    Pipeline(steps=[('gap1',
#                                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                                    ('gap2',
#                                                                                     SimpleImputer(missing_values=' ',
#                                                                                                   strategy='most_frequent'))])),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
# ...

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Очень важно также проверить лучшую модель на адекватность, сравнив качество её предсказаний с качеством модели, которая предсказывала бы константу - вдруг окажется, что не было бы большого смысла заниматься созданием новых признаков, тюнингом и кросс-валидацией моделей, если можно было бы просто предсказывать среднее значение тренировочной выборки?
#
# В качестве константной модели можно использовать `DummyRegressor` (https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyRegressor.html) -  эта модель как раз создана для генерирования константных предсказаний.
#
# Важно, чтобы результат тестирования нашей модели на тествой выборке был лучше, чем результат константной модели - в противном случае наша модель является бесполезной, так как все наши усилия над проектом не принесли результата, а можель, просто предсказывющая среднее на `train`, делает нашу работу лучше.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Добавил. DummyRegressor так понимаю усилий особо не требует и его можно на тестовой выборке тоже запустить.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Ты прав. Кросс-валидацию для константной модели делать не нужно: так как процесс её "обучения" сводится к простому запоминанию агрегата по тренировочной выборке, то каким-то образом влиять на процесс обучения через подбор гиперпараметров мы не можем. Кроме того, проблемы недо- или переобучения в данном случае также неактуальны, поэтому в кросс-валидации как в инструменте борьбы с этими проблемами нет большого смысла.
#
# Оценивать качество константной модели нужно аналогично оценке качества твоей лучшей модели - сначала обучаемся на `train`, затем делаем предикты для `test`, а далее уже оцениваем их качество.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Да , действительно , и параметры там подбирать ненужно...Поправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ## Задача 2

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Для этой задачи аналогичны все замечания из предыдущей в части аналогичных активностей.

# %% [markdown]
# ### Предобработка

# %% [markdown]
# #### Категорийные признаки.

# %%
df_cat_columns = ['dept','level','workload','last_year_promo','last_year_violations','quit' ]
for i in df_cat_columns:
    print(df2[i].unique())
# Out:
# ['sales' 'purchasing' 'marketing' 'technology' 'hr']
# ['middle' 'junior' 'sinior']
# ['high' 'medium' 'low']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']

# %% [markdown]
# Исправляем опечатку.

# %%
df2.loc[df2['level']=='sinior','level'] = 'senior'

# %%
z_test['quit'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %% [markdown]
# #### Пропуски

# %% [markdown]
# Выполняем те же шаги что и в первой задаче.

# %%
df2.isna().sum()
# Out:
# dept                     0
# level                    0
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# quit                     0
# dtype: int64

# %% [markdown]
# #### Аномалии

# %%
df2.describe()
# Out:
#        employment_years  supervisor_evaluation        salary
# count       4000.000000            4000.000000   4000.000000
# mean           3.701500               3.474750  33805.800000
# std            2.541852               1.004049  15152.415163
# min            1.000000               1.000000  12000.000000
# 25%            2.000000               3.000000  22800.000000
# 50%            3.000000               4.000000  30000.000000
# 75%            6.000000               4.000000  43200.000000
# max           10.000000               5.000000  96000.000000

# %%
X_test = X_test.sort_index()
z_test = z_test.sort_index()
(X_test.index != z_test.index).sum()
# Out:
# 0

# %% [markdown]
# #### Дубликаты

# %% [markdown]
# Как и в первой части есть много дубликатов.

# %%
df2.duplicated().sum()
# Out:
# 1413

# %%
X_test.duplicated().sum()
# Out:
# 561

# %% [markdown]
# В тестовом датасете дубликаты удалять не будем т.к. они не влияют на обучение модели.

# %% [markdown]
# #### Выводы

# %% [markdown]
# Данные без пропусков и аномалий , было много дубликатов их удалили.

# %% [markdown]
# ### Исследовательский анализ

# %% [markdown]
# #### Гистограммы обших данных.

# %% [markdown]
# Проводим , как и раньше осмотр графиков всех признаков.

# %%
analysis(df2)
# Out:
# Список неприрывных признаков ['salary']
# Список дискретныйх признаков ['employment_years', 'supervisor_evaluation']
# Список категорийных признаков ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations', 'quit']
# ----------------------------------------
# Графики неприрывных признаков
# p=1.09e-39 Вероятно не нормальное
#              salary
# count   4000.000000
# mean   33805.800000
# std    15152.415163
# min    12000.000000
# 25%    22800.000000
# 50%    30000.000000
# 75%    43200.000000
# max    96000.000000
# ----------------------------------------
# Графики дискретных признаков
# ----------------------------------------
# Графики категорийных признаков

# %% [markdown]
# Данные похожи по паспределению на df. Отметим, что в целевом признаке есть дисбаланс классов. Это наблюдение пригодится при построении модели и выборе метрики.

# %% [markdown]
# #### «Портрет» уволившегося сотрудника.

# %% [markdown]
# Посмотрим отличаются ли распределения по признакам а зависимости от того уволился сотрудник или нет.

# %%
df2.pivot_table(index='quit',\
                values=['salary','employment_years', 'supervisor_evaluation'],\
                aggfunc='describe').T
# Out:
# quit                                   no           yes
# employment_years      25%        2.000000      1.000000
#                       50%        4.000000      1.000000
#                       75%        6.000000      2.000000
#                       count   2872.000000   1128.000000
#                       max       10.000000     10.000000
#                       mean       4.430710      1.844858
#                       min        1.000000      1.000000
#                       std        2.544635      1.274920
# salary                25%    25200.000000  16800.000000
#                       50%    34800.000000  22800.000000
#                       75%    46800.000000  27600.000000
#                       count   2872.000000   1128.000000
#                       max    96000.000000  79200.000000
#                       mean   37702.228412  23885.106383
#                       min    12000.000000  12000.000000
#                       std    15218.977339   9351.599505
# ...

# %% [markdown]
# Уже тут видно что группы заметно отличаются. Увольняющиеся это сотрудники с небольшим стажем работы медиана 1год. Зарплата так же более низкая, медиана почти в 1.5 раза ниже. При этом оцанка качества работы ниже чем у остающихся.

# %%
cat = ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']
for i in cat:
    a = df2[i].unique().tolist()
    b = df2.loc[df2['quit']=='yes'].pivot_table(index=i,values='salary',aggfunc='count')['salary']
    c = df2.loc[df2['quit']=='no'].pivot_table(index=i,values='salary',aggfunc='count')['salary']
    
    a_axis = np.arange(len(a)) 
  
    plt.bar(a_axis - 0.2, c/df2.shape[0], 0.4, label = 'Остались') 
    plt.bar(a_axis + 0.2, b/df2.shape[0], 0.4, label = 'Уволились') 
  
    plt.xticks(a_axis, a) 
    plt.xlabel(i) 
    plt.ylabel("Доля сотрудников") 
    plt.title(f"Зависимость доли сотрудников от {i}") 
    plt.legend() 
    plt.show()

# %% [markdown]
# После анализа гистограм к портрету можно добавить, что уходяший это мидл,который работал бкз повышения.
# Большая доля относительно оставшихся уходит со средней загрузки работой. По отделам соотношения близкие, из самого многочисленного отдела уходит в абсолютном выражении больше всего сотрудников.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Проанализирован портрет уволившегося сотрудника. Молодец, что посчитал средние для непрерывного признака.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Анализ категориальных/дискретных признаков нужно сделать с помощью относительных величин - оперировать абсолютными величинами не всегда удобно, так как в зависимости от масштаба исследования (компания на 100 человек и компания на 100 000 человек, например) результаты могут быть более или менее интерпретируемыми. Для категориальных/дискретных признаков мы можем использовать `value_counts(normalize=True)`, для непрерывных можно посчитать и сравнить средние.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Поправил.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# #### Связь с job_satisfaction_rate.

# %% [markdown]
# Построим плотности распределения по индексу удовлетворенности для обоих классов.

# %%
yz = pd.DataFrame()
yz['y'] = y_test['job_satisfaction_rate']
yz['z'] = z_test['quit']
sns.kdeplot(data=yz ,x='y',hue='z',common_norm=False)
plt.ylabel("Плотность распределения сотрудников") 
plt.xlabel("Индекс удовлетворенности") 
plt.title(f"Плотность распределения сотрудников от индекса удовлетворенности") 
plt.legend(['Остались','Уволились']) 
plt.show()

# %% [markdown]
# Проверим спомощью ttest гипотезу что средние показатели индекса удовлетворенности по классам равны.

# %%
a = y_test[z_test['quit']=='yes']['job_satisfaction_rate']
b = y_test[z_test['quit']=='no']['job_satisfaction_rate']
print(b.mean(),a.mean())
print(b.var(),a.var())
# Out:
# 0.6120403899721449 0.38771276595744686
# 0.03974726247901158 0.03451571841578171

# %% [markdown]
# Дисперсии близки применяем двувыборочный ттест с равными дисперсиями.

# %%
stat, p = stats.ttest_ind(a=a, b=b, equal_var=True)
if p>0.05:
    print(f'p={p:.3} Гипотеза не опровергнута')
else :
    print(f'p={p:.3} Гипотеза опровергнута')
# Out:
# p=1.23e-104 Гипотеза опровергнута

# %% [markdown]
# Видно что средние по классам не равны , а значит у удовлетворенности и увольнением есть связь.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследовано распределение удовлетворённости в зависимости от факта ухода.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Чуть более интересным решением, позволяющим выполнить оценку не "на глаз", а более статистически достоверно, было бы использование статистического теста (например, `ttest`) для сравнения распределений в выборках.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не забывай формулировать гипотезы, это очень важный момент.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Гипотезы так и не появились - их обязательно нужно формулировать при проведении тестов.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v.4 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> В целом можно зачесть, но обрати внимание, что гипотезы формулируются парами - нулевая и альтернативная.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Здесь мы имеем дело с анализом распределения непрерывной величины, а сам анализ проводится по двум выборкам разного размера - для анализа их распределения стоит использовать нормированную гистограмму (например, `shs.histplot()` с параметрами `stat='density', common_norm=False` или `sns.kdeplot()`): гистограммы такого типа позволяют нивелировать разницу в размерах выборок при анализе распределений. Обрати также внимание, что при использовании нормированных гистограмм по оси Y будет уже не частота значений, а плотность распределения.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Да так гораздо 'красивее' получается, спасибо.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# #### Вывод

# %% [markdown]
# Составили примерный портрет уволившегося сотрудника. Это мидл, с небольшим сроком работы, с низкой зарплатой, с пониженой оценкой эффективности и низким уровнем удовлетворенности.
#
# Была показана связь индекса удовлетворенности и увольнений. Средняя оценка увалившихся 0.4 , а оставшихся 0.6.
#
# При анализе распределений видим тоже что было в первой задаче.
# (В тренировочной выборке и тестовой выборке распределения одих признаков близки.
# - Salary распределение далеко от нормального есть длинный хвост из выбросов в сторону высокой зарплаты.
# - Job_satisfaction_rate так же распределение не нормальное. Есть несколько пиков на 0.4 и 0.7.
# - employment_years Видно что число сотрудников почти линейно падает в зависимости от стажа.
# - supervisor_evaluation Преобладающая оценка 4 и 3. 5 и 2 мало. 1 редкость.
# - dept самый популярный департамент sales  затем technology. Остальные 3 примерно на одном уровне.
# - level . junior middle примерно равны по численности , senior гораздо меньше.
# - workload Сотрудников со средней загрузкой больше всего , затем идут с низкой нагрузкой, и меньше всего сотрудников с высокой нагрузкой.
# - last_year_promo Сотрудников которых повышели очень мало.
# - last_year_violations нарушителей тоже мало относительно не нарушавших.)

# %% [markdown]
# ### Корреляционный анализ.

# %% [markdown]
# #### Добавляем признак job_satisfaction_rate_p

# %% [markdown]
# Поскольку на тестовой выбокре была выявлена связь между индексом удовлетворенности и увольнением добавим в таблицу индекс удовлетворенности используя обученую в задаче 1 модель.

# %%
df2['job_satisfaction_rate_p'] = random_search.best_estimator_.predict(df2.drop('quit',axis=1))
X_test['job_satisfaction_rate_p'] = random_search.best_estimator_.predict(X_test)
df2
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 723290       sales  middle     high                 2              no
# 814010       sales  junior   medium                 2              no
# 155091  purchasing  middle   medium                 5              no
# 257132       sales  junior   medium                 2              no
# 910140   marketing  junior   medium                 2              no
# ...            ...     ...      ...               ...             ...
# 588809       sales  junior   medium                 4              no
# 672059       sales  middle     high                 9              no
# 536432  purchasing  junior      low                 2              no
# 692133  purchasing  middle   medium                 2              no
# 853842       sales  junior   medium                 2              no
#
#        last_year_violations  supervisor_evaluation   salary quit  \
# id
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В выборки добавлены новые признаки.

# %% [markdown]
# Поскольку распределение признаков не является нормальным, для поиска корреляций будем использовать кореляции Спирмана и $\phi_k$.

# %% [markdown]
# #### Тренировочные данные.

# %% [markdown]
# ##### Корреляция Спирмена

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df2.corr(method='spearman'),annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# ##### Корреляция  $\phi_k$

# %%
con = df2.select_dtypes(include=['float']).columns.tolist()
plt.figure(figsize=(10,10))
sns.heatmap(df2.phik_matrix(interval_cols=con),annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# Построим также таблицы для каждого класса.
# - Не уволились
# - Уволились

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df2[df2['quit']=='no'].phik_matrix(interval_cols=con),annot=True, fmt='.2f')
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/phik/data_quality.py:82: UserWarning:
#
# Not enough unique value for variable quit for analysis 1. Dropping this column

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df2[df2['quit']=='yes'].phik_matrix(interval_cols=con),annot=True, fmt='.2f')
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/phik/data_quality.py:82: UserWarning:
#
# Not enough unique value for variable quit for analysis 1. Dropping this column

# %% [markdown]
# #### Тестовые данные.

# %% [markdown]
# Для тестовых данных кроме целевого признака корреляции уже были , но повторимся.

# %%
X_test['quit'] = z_test['quit']

# %% [markdown]
# ##### Корреляция Спирмена

# %%
plt.figure(figsize=(10,10))
sns.heatmap(X_test.corr(method='spearman'),annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# ##### Корреляция  $\phi_k$

# %%
con = X_test.select_dtypes(include=['float']).columns.tolist()
plt.figure(figsize=(10,10))
sns.heatmap(X_test.phik_matrix(interval_cols=con),annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# Построим также таблицы для каждого класса.
# - Не уволились
# - Уволились

# %%
plt.figure(figsize=(10,10))
sns.heatmap(X_test[X_test['quit']=='no'].phik_matrix(interval_cols=con),annot=True, fmt='.2f')
plt.show()
# Out:
# /opt/conda/lib/python3.9/site-packages/phik/data_quality.py:82: UserWarning:
#
# Not enough unique value for variable quit for analysis 1. Dropping this column

# %%
plt.figure(figsize=(10,10))
sns.heatmap(X_test[X_test['quit']=='yes'].phik_matrix(interval_cols=con),annot=True, fmt='.2f')
plt.show()
X_test = X_test.drop('quit',axis=1)
# Out:
# /opt/conda/lib/python3.9/site-packages/phik/data_quality.py:82: UserWarning:
#
# Not enough unique value for variable quit for analysis 1. Dropping this column

# %% [markdown]
# #### Вывод.

# %% [markdown]
# Хотя мы добавили признак, который является комбинацией других, мултиколлинеарность не появилась.
# Можно отметить, что целевой признак коррелирует со всеми остальными кроме дапартамента. В остальном выводы теже что были в 1 задаче.
# (Мультиколлинеарности нет.
# Матрицы для обоих видов корреляции в случае тестовой и тренировочной выборки почти совпадают. т.е. Если есть корреляция в тестовой выборке она есть и ее величина почти та же, что и в тренировочной, и наоборот. Значит модель, обученая на данных тренировочной выборки, будет работать и на тестовой выборке с высокой вероятностью. )

# %% [markdown]
# ### Обучение модели

# %% [markdown]
# Будем обучать 4 модели с подбором параметров при кросс-валидации.
# - DecisionTreeClassifier
# - CSV
# - LogisticRegression
# - KNeighborsClassifier
# Попробуем при этом 3 варианта тренировочной выборки с job_satisfaction_rate_p , без него и с дубликатами из тренировочной выборки.

# %%
#Удаляем дубликаты
df2_duplicates = df2.copy(deep=True)
df2 = df2.drop_duplicates()
df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Создаем список параметров.

# %%
param_grid_2 = [
    #словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': [None] + [i for i in range(3, 7)],
        'models__min_samples_leaf': range(2 , 5),
        'models__min_samples_split': range(2 , 5),
        'preprocessor__num': [StandardScaler()] 
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(10,50),
        'preprocessor__num': [StandardScaler()]   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C':range(1,5),
        'preprocessor__num': [RobustScaler()]  
    },
    
    # словарь для модели SVC()
    {
        'models': [SVC( probability=True,random_state=RANDOM_STATE)],
        'models__kernel':['rbf'],
        'models__C':range(1,10),
        'preprocessor__num': [MinMaxScaler()]  

    }
]

# %% [markdown]
# - Вариант с job_satisfaction_rate_p.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# На `test` оцениваем только одну модель, лучшую по итогам кросс-валидации. Эта концепция находит своё отражение в условиях эксплуатации модели в реальной среде: в промышленной эксплуатации не работает несколько моделей одновременно - в промышленную эксплуатацию запускают только одну модель, которая была выбрана из нескольких в ходе промежуточной оценки. Так же и здесь - тестовая выборка имитирует поток реальных данных, и с этим потоком должна работать только одна модель.
#
# Это касается как подбора гиперпараметров, так и экспериментов с числом признаков - все эксперименты мы проводим на кросс-валидации, а итоговую оценку на `test` проводим только с лучшим экспериментом.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Сделано
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# Создадим тренировочные выборки.

X_train = df2.drop(['quit'],axis=1)
z_train = df2['quit']

X_train.shape, z_train.shape
# Out:
# ((2587, 9), (2587,))

# %% [markdown]
# Закодируем целевой признак `LabelEncoder`

# %%
le = LabelEncoder()
z_train_le = le.fit_transform(z_train)
z_test_le = le.transform(z_test['quit'])

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не выполнено кодирование целевого признака - для этого нужно использовать `LabelEncoder`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# Случайный поиск с кроссвалидацией. Вариантов гиперпараметров много. 
random_search_2 = RandomizedSearchCV(
    pipe_final, 
    param_grid_2, 
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    n_iter=50,
    random_state=RANDOM_STATE
)
random_search_2.fit(X_train, z_train_le)

print ('Метрика лучшей модели при кросс-валидации :', random_search_2.best_score_)
print('Лучшая модель и её параметры:')
# Выводим лучшую модель и параметры
display(random_search_2.best_estimator_)
display(random_search_2.best_params_)
    
    # Выводим топ моделей.
    
result = pd.DataFrame(random_search_2.cv_results_)
print(result[
    ['rank_test_score', 'param_models', 'mean_test_score']
    ].sort_values('rank_test_score'))
# Out:
# Метрика лучшей модели при кросс-валидации : 0.9056964723777027
# Лучшая модель и её параметры:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('gap',
#                                                                    Pipeline(steps=[('gap1',
#                                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                                    ('gap2',
#                                                                                     SimpleImputer(missing_values=' ',
#                                                                                                   strategy='most_frequent'))])),
#                                                                   ('ohe',
# ...

# %% [markdown]
# - Вариант без job_satisfaction_rate_p .

# %%
random_search_2 = RandomizedSearchCV(
    pipe_final, 
    param_grid_2, 
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    n_iter=50,
    random_state=RANDOM_STATE
)
random_search_2.fit(X_train.drop('job_satisfaction_rate_p',axis=1), z_train_le)

print ('Метрика лучшей модели при кросс-валидации :', random_search_2.best_score_)
print('Лучшая модель и её параметры:')
# Выводим лучшую модель и параметры
display(random_search_2.best_estimator_)
display(random_search_2.best_params_)
# Out:
# Метрика лучшей модели при кросс-валидации : 0.904571978745863
# Лучшая модель и её параметры:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('gap',
#                                                                    Pipeline(steps=[('gap1',
#                                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                                    ('gap2',
#                                                                                     SimpleImputer(missing_values=' ',
#                                                                                                   strategy='most_frequent'))])),
#                                                                   ('ohe',
# ...

# %% [markdown]
# - Тренировочная выборка с дубликатами. Поскольку в тестовой выборке и в тренировойчной очень много дубликатов предположим, что они там не случайны. И обучим модель на выборке с дубликатами.

# %%
df2_duplicates['job_satisfaction_rate_p'] = random_search.best_estimator_\
.predict(df2_duplicates.drop('quit',axis=1))
X_train_duplicates = df2_duplicates.drop(['quit'],axis=1)
z_train_duplicates = df2_duplicates['quit']
z_train_duplicates_le = le.transform(z_train_duplicates)

X_train_duplicates.shape, z_train_duplicates_le.shape
# Out:
# ((4000, 9), (4000,))

# %%
random_search_2 = RandomizedSearchCV(
    pipe_final, 
    param_grid_2, 
    cv=5,
    scoring='roc_auc',
    n_jobs=-1,
    n_iter=50,
    random_state=RANDOM_STATE
)
random_search_2.fit(X_train_duplicates, z_train_duplicates_le)

print ('Метрика лучшей модели при кросс-валидации :', random_search_2.best_score_)
print('Лучшая модель и её параметры:')
# Выводим лучшую модель и параметры
display(random_search_2.best_estimator_)
display(random_search_2.best_params_)

 # Выводим топ моделей.
    
result = pd.DataFrame(random_search_2.cv_results_)
print(result[
    ['rank_test_score', 'param_models', 'mean_test_score']
    ].sort_values('rank_test_score'))
# Out:
# Метрика лучшей модели при кросс-валидации : 0.928059998698135
# Лучшая модель и её параметры:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('gap',
#                                                                    Pipeline(steps=[('gap1',
#                                                                                     SimpleImputer(strategy='most_frequent')),
#                                                                                    ('gap2',
#                                                                                     SimpleImputer(missing_values=' ',
#                                                                                                   strategy='most_frequent'))])),
#                                                                   ('ohe',
# ...

# %%
    # Метрика на тестовой выборке.
z_test_pred_proba = random_search_2.predict_proba(X_test)[:,1]
metric = roc_auc_score(z_test_le,z_test_pred_proba)
print(f'Метрика ROC-AUC на тестовой выборке: {metric}')

# Кривая ROC-AUC 
    
fpr, tpr, threshold = roc_curve(z_test_le, z_test_pred_proba, pos_label=1)

plt.plot(fpr, tpr)
plt.title("График зависимости FPR от TPR")
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.show()
    
    # Матрица ошибок

z_test_pred = random_search_2.predict(X_test)
cm = confusion_matrix(z_test_le, z_test_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues_r')
plt.ylabel('True label')
plt.xlabel('Predicted')
plt.show()
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.9283600278551533

# %% [markdown]
#  Видим что модель обученая на выборке с дубликатами работает значительно лучше при кросс - валидации. Стоит подробнее изучить почему возникают дубликаты.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Напомню, что целевая метрика проекта - `AUC-ROC`, которая нечувствительна к дисбалансу, балансировать классы или учитывать дисбаланс при работе с моделями не нужно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Балансировку классов обязательно нужно делать в составе `Pipeline`, чтобы не допускать искажения классов в оценивающем фолде. Обрати внимание, что нужно использовать `Pipeline` из `imblearn`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Раз не очень надо, то и не буду этот шаг делать тогда.С пайплайнами не сильно уверенно себя чувствую... Скорее просто интересно было повлияет ли это как-то на метрику или нет. Понятно что не должно сильно.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Да, в целом можно не делать.

# %% [markdown]
# <div class="alert alert-info">
# Комментарий для проверяющего:
#     -тут все сделал по теории c sampler. Почему Only one class present in y_true не очень понимаю просьба подсказать.
#
# И еще вопрос. Я сделал пайплайн в нем сидят списки признаков num, cat, ord_cat. А потом хочу их поменять (добавить новые или убрать старые) как это сделать лучше? Засунуть пайплайн в функцию?
#
# Так же хотелось бы посчитать важность признаков, но моя борьба с shap к успеху не привела , по этому тоже прошу подсказать. Заготовка кода ниже .
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Судя по логу ошибки, у тебя в `y_true` только одно значение класса, поэтому алгоритм не может посчитать метрику. Проверь корректность своей балансировки, в том числе учти замечание о процессе его проведения.
#
# Обрати также внимание, что текущее значение метрики не удовлетворяет требованию `AUC-ROC >= 0.91`. В процессе подготовки данных, кроме дубликатов, нет явных ошибок, поэтому стоит сфокусировать условие на поиске лучшей модели - попробовать другие гиперпараметры/модели.
#
# По `SHAP` - попытался запустить код, но платформа пока его не может осилить. Попробую запустить в другом окружении и попытаюсь прийти с ответом на следующей итерации. Но в целом, вопросы из серии "почему не работает" стоит задавать преподавателю по проектам - они смогут в более оперативном формате давать обратную связь, чтобы исключить случаи, когда невыполненное задание будет блокером для начала работы над проектом.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Да спасибо преподавателю тоже задал вопрос пока не ответил. По  заданию так понял шаг не обязательный , но хотелось бы разобраться, инструмент кажется полезным.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Получилось в таком виде:
#
#     num = ['salary','employment_years', 'supervisor_evaluation','job_satisfaction_rate_p']
#     cat = ['dept', 'last_year_promo', 'last_year_violations']
#     ord_cat = ['level','workload']
#
#     data_preprocessor_2 = ColumnTransformer(
#     [
#         ('ohe', ohe_pipe, cat),
#         ('ord', ord_pipe, ord_cat),
#         ('num', MinMaxScaler(), num)
#     ],
#     remainder='passthrough'
#     )
#
#     X_train_p = pd.DataFrame(
#     data_preprocessor_2.fit_transform(X_train),
#     columns=data_preprocessor_2.get_feature_names_out()
#     )
#
#     X_test_p = pd.DataFrame(
#     data_preprocessor_2.transform(X_test),
#     columns=data_preprocessor_2.get_feature_names_out()
#     )
#
#
#     best_model = SVC(C=3, probability=True, random_state=42)
#     best_model.fit(X_train_p,z_train)
#
#     explainer = shap.KernelExplainer(best_model.predict_proba, X_train_p)
#     shap_values = explainer.shap_values(X_test_p, nsamples=100)

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Спасибо, заработало!
#
# </div>

# %% [markdown]
# #### Важность признаков.

# %% [markdown]
# Посчитаем значения Шепли для признаков в лучшей модели выбранной выше.

# %%
num = ['salary','employment_years', 'supervisor_evaluation','job_satisfaction_rate_p']
cat = ['dept', 'last_year_promo', 'last_year_violations']
ord_cat = ['level','workload'] 

data_preprocessor_2 = ColumnTransformer(
[
    ('ohe', ohe_pipe, cat),
    ('ord', ord_pipe, ord_cat),
    ('num', MinMaxScaler(), num)
], 
remainder='passthrough'
)

X_train_p = pd.DataFrame(
data_preprocessor_2.fit_transform(X_train),
columns=data_preprocessor_2.get_feature_names_out()
)

X_test_p = pd.DataFrame(
data_preprocessor_2.transform(X_test),
columns=data_preprocessor_2.get_feature_names_out()    
)

X_test_p_sample = X_test_p.sample(n=50,random_state=RANDOM_STATE)
X_train_p_sample = X_train_p.sample(n=50,random_state=RANDOM_STATE)

best_model = SVC(C=3, probability=True, random_state=42)
best_model.fit(X_train_p,z_train)

explainer = shap.KernelExplainer(best_model.predict_proba,X_train_p_sample)

shap_values = explainer(X_test_p_sample)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
fig, ax = plt.gcf(), plt.gca()

# Modifying main plot parameters
ax.tick_params(labelsize=14)
ax.set_xlabel("Средние значения Шепли", fontsize=14)
ax.set_ylabel("Признаки", fontsize=14)
ax.set_title('Важность признаков', fontsize=14)


shap.plots.bar(shap_values[:,:,1], max_display=12)

plt.show()

# %%
fig, ax = plt.gcf(), plt.gca()


# Modifying main plot parameters
ax.tick_params(labelsize=14)
ax.set_xlabel("Средние значения Шепли", fontsize=14)
ax.set_ylabel("Значения признаков", fontsize=14)
ax.set_title('Важность признаков', fontsize=14)

# Get colorbar
cb_ax = fig.axes[0]

# Modifying color bar parameters
cb_ax.tick_params(labelsize=15)
cb_ax.set_ylabel("Признаки", fontsize=14)
cb_ax.set_xlabel("Средние значения Шепли", fontsize=14)

shap.plots.beeswarm(shap_values[:,:,1], max_display=12)

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не забывай подписывать ось Y и название на графике. Так как `SHAP` график тоже является визуальным объектом, для его кастомизации мы можем использовать методы plt, как и для других графиков, однако это потребует небольшой настройки самого объекта `SHAP`. Подробнее можно глянуть тут: https://github.com/shap/shap/issues/594.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Как там написано подписал заголовок и левую ось y. Как Х и правую ось переименовать не смог понять. Просто по аналогии дописать xlabel, как видно, не прокатило.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.4 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Правую не нужно - достаточно подписать левую:)

# %% [markdown]
# ### Вывод

# %% [markdown]
# Лучщей моделью для предсказания целевого признака 'quit' оказался метод опорных векторов. Спараметрами
# - MinMaxScaler(),
# - kernel: rbf,
# - C = 2,
# Метрика на тестовой выборке составила ROC-AUC = 0.928.
# Можно отметить, что все модели кроме логистической регрессии справились хорошо разница между ними только в третем знаке. Это не удивительно т.к. данные распределены не нормально и есть выбросы.
# Несмотря на то что job_satisfaction_rate получен из тех же данных этот признак немного улучшает метрики модели.
# Наиболее важные признаки в порядке уменьшения значимости: level, job_satisfaction_rate,employment_years, workload, supervisor_evaluation . Фактически те же что были в первой задаче.

# %% [markdown]
# ## Общий вывод.

# %% [markdown]
# Компания предоставила данные с характеристиками сотрудников компании.
# Первая задача — построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
# Ваша вторая задача — построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.
#
# Исходные данные были загружены и проверены на корректность. Затем была проведена предобработка, в ходе которой были были заполнены пропуски. Дубликатов данные не содержали.
#
# Для решения первой задачи были проведены следующие шаги:
# - Были изучены распределения всех признаков. Аномалий выявлено не было. Большинство распределений далеки от нормальной формы.
# - Затем проведен корреляционный анализ по методам Спирмена и $\phi_k$, убедились в том что целевой признак действительно связан с остальными и данные не содержат мультиколлинеарности.
# - После этого прешли к составлению модели для этого создан пайплайн, который используя кросс-валидацию с метрикой SMAPE позволил выбрать оптимальные гиперпараметры и скейлинг для численных для модели DecisionTreeRegresor и LogisticRegression. Поскольку данные были распределены не нормально и с выбросами, то лучше оказалась модель  DecisionTreeRegresor с параметрами  MinMaxScaler , min_samples_split = 5  , min_samples_leaf = 3 max_depth = none, и метрикой SMAPE = 13.5% , что лучше требуемых заказчиком 15% LogisticRegression показала метрику SMAPE = 23.6% на тестовой выборке.
# Таким образом мы выбрали и обучили модель которая предсказывает удовлетворенность сотрудников с нужной точностью.
#
# Во второй задаче порядок действий был похожим.
# - Были изучены распределения всех признаков. Аномалий выявлено не было. Большинство распределений далеки от нормальной формы. Благодаря различиям в распределениях для разных классов удалось построить портрет сотрудника который увольняется это сотрудники уровня мидл с небольшим стажем работы (медиана 1год) Зарплата так же более низкая, медиана почти в 1.5 раза ниже чем у остающихся. При этом оцанка качества работы ниже чем у остающихся. Так же была выявлена связь с целевым признаком задачи 1. У увольняющихся  низким уровнем удовлетворенности в среднем 0.4 против 0.7 у остающихся.
# - Затем проведен корреляционный анализ по методам Спирмена и $\phi_k$, убедились в том что целевой признак действительно связан с остальными и данные не содержат мультиколлинеарности.
# - Затем с использоватием пайплайна и кросс-валидации была отобрана лучшая модель с гиперпараметрами для предсказания увольнения сотрудников (целевой признак quit). Все модели показали близкий результат , кроме логистической регрессии по тем же причинам что и в первой задаче. Однако лучшей моделью оказался метод опорных векторов с параметрами  MinMaxScaler, kernel =rbf ,C = 2. Метрика ROC_AUC на тестовой выборке 92.8 , что так же удовлетворяет требованиям заказчика.
# Была выбрана и обучена модель которая предсказывает факт увольнения сотрудников с нужной точностью.
#
# Исходя из портрета увольняющегося. корреляционных данных и анализа важнсти признаков можно дать несколько рекомендаций чтобы избежать увольнения новых сотрудников обратить внимаение на категорию мидл, платить более высокую зарплату , стараться держать рабочую нагрузку на приемлемом уровне, мотивировать руководителей разбираться почему у сотрудников низкая оценка. Возможно выработать более подробные критерии для оценки уководителей для улучшения качества моделей.   .
#
# Так же рекомендация проверить почему в данных большое количество дубликатов сотрудников с разними Id. Является ли это ошибкой или действительно есть много сотрудников со схожими параметрами.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Есть итоговый вывод и рекомендации для бизнеса.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Андрей, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Работа с моделями также выполнена отлично: исследовано несколько алгоритмов, проведён подбор гиперпараметров с помощью `RandomizedSearchCV`, выполнена промежуточная оценка моделей на кросс-валидации - молодец! Здорово, что используешь сочетание `ColumnTransformer` и `Pipeline` для соединения разных инструментов в единый модельный объект и настраиваешь бесперебойную работу энкодера в случае появления в данных новых, неизвестных на момент обучения значений признаков - так твоё решение будет более гибким и масштабируемым.
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
# Благодарю за советы! по возможности все поправил.
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: итоговый вывод по проекту.
#
# Андрей, все замечания учтены - проект принят!
#
# Спасибо за хорошую работу над проектом, желаю успехов в дальнейшем обучении:)
